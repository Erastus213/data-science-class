# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    "EmpId": [101, 102, "103", 104, 105, 106, 107, 108, 109, 110],
    "fullName": [
        "  Alice Johnson  ", "MICHEAL smith", "sarah lee", "David-Kim", None, "john brown",
        "Emma Wilson", "TOM  davis", "Jane Miller", "Chris taylor"
    ], 
     "Dept": ["IT", "hr", "Mktng", "IT", "Customer Care", "marketing", "Finance", None, "HR", "marketing"],
    "Age": [29, "thirty-five", 26, 31, 42, 27, 33, 30, None, 28],
    "Salary($)": ["$5500.50", "4800", "4200.75", "NaN", "6100", "4,300", "5800", "5000", "4700.0", "4400"],
    "JoinDate" : [ 
        "12-04-2021" , "2020.11.01" , "Jan 18, 2022" , "2019/9/25" , "07/05/18" , "2021-10-14" , 
        "2019/12/01" , "2020-03-22" , "May 10th, 2021" , "2022-02-05" 
    ],
    "Performance": [87, "73", 90, 65, 82, 75, 88, None, "79%", "91"],
    "Remote?": ["Yes", "No", "Y", "N", "yes", "no", "Y", "Yes", None, "True"]
}

# %%
#create a dataframe for the data
df = pd.DataFrame(data)

#convert the daraframe to csv file
df1 =  df.to_csv("employee_data.csv", index=False)

#load dataset
df = pd.read_csv("employee_data.csv")

df.head()
# Out:
#    EmpId           fullName           Dept          Age Salary($)  \
# 0    101    Alice Johnson               IT           29  $5500.50
# 1    102      MICHEAL smith             hr  thirty-five      4800
# 2    103          sarah lee          Mktng           26   4200.75
# 3    104          David-Kim             IT           31       NaN
# 4    105                NaN  Customer Care           42      6100
#
#        JoinDate Performance Remote?
# 0    12-04-2021          87     Yes
# 1    2020.11.01          73      No
# 2  Jan 18, 2022          90       Y
# 3     2019/9/25          65       N
# 4      07/05/18          82     yes

# %%
#the shape 
df.shape
# Out:
# (10, 8)

# %%
#getting information on the dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmpId        10 non-null     int64
#  1   fullName     9 non-null      str
#  2   Dept         9 non-null      str
#  3   Age          9 non-null      str
#  4   Salary($)    9 non-null      str
#  5   JoinDate     10 non-null     str
#  6   Performance  9 non-null      str
#  7   Remote?      9 non-null      str
# dtypes: int64(1), str(7)
# memory usage: 1.1 KB

# %%
#get columns from dataset
df.columns
# Out:
# Index(['EmpId', 'fullName', 'Dept', 'Age', 'Salary($)', 'JoinDate',
#        'Performance', 'Remote?'],
#       dtype='str')

# %%
#get missing value count
df.isnull().sum()
# Out:
# EmpId          0
# fullName       1
# Dept           1
# Age            1
# Salary($)      1
# JoinDate       0
# Performance    1
# Remote?        1
# dtype: int64

# %%
#get unique values columns
print(df["Dept"].unique())
print(df["Age"].unique())
print(df["Remote?"].unique())
# Out:
# <ArrowStringArray>
# ['IT', 'hr', 'Mktng', 'Customer Care', 'marketing', 'Finance', nan, 'HR']
# Length: 8, dtype: str
# <ArrowStringArray>
# ['29', 'thirty-five', '26', '31', '42', '27', '33', '30', nan, '28']
# Length: 10, dtype: str
# <ArrowStringArray>
# ['Yes', 'No', 'Y', 'N', 'yes', 'no', nan, 'True']
# Length: 8, dtype: str

# %%
df["Salary($)"].head()
# Out:
# 0    $5500.50
# 1        4800
# 2     4200.75
# 3         NaN
# 4        6100
# Name: Salary($), dtype: str

# %%
#start cleaning incosistent values
#rename inconsistent columns
df.rename(columns={
    "EmpId": "Employee ID",
    "fullName": "Full Name",
    "Dept": "Department",
    "Salary($)": "Salary",
    "JoinDate": "Join Date",
    "Remote?": "Remote",
}, inplace=True)

df
# Out:
#    Employee ID          Full Name     Department          Age    Salary  \
# 0          101    Alice Johnson               IT           29  $5500.50
# 1          102      MICHEAL smith             hr  thirty-five      4800
# 2          103          sarah lee          Mktng           26   4200.75
# 3          104          David-Kim             IT           31       NaN
# 4          105                NaN  Customer Care           42      6100
# 5          106         john brown      marketing           27     4,300
# 6          107        Emma Wilson        Finance           33      5800
# 7          108         TOM  davis            NaN           30      5000
# 8          109        Jane Miller             HR          NaN    4700.0
# 9          110       Chris taylor      marketing           28      4400
#
#         Join Date Performance Remote
# 0      12-04-2021          87    Yes
# 1      2020.11.01          73     No
# 2    Jan 18, 2022          90      Y
# 3       2019/9/25          65      N
# 4        07/05/18          82    yes
# 5      2021-10-14          75     no
# 6      2019/12/01          88      Y
# 7      2020-03-22         NaN    Yes
# 8  May 10th, 2021         79%    NaN
# 9      2022-02-05          91   True

# %%
#to display and check all values under a column
df["Full Name"] = (
    df["Full Name"]
    .str.strip()
    .str.title()
    .str.replace(r"[\s-]+", " ", regex=True)
    .tolist()
)
df["Full Name"].to_list()
# Out:
# ['Alice Johnson',
#  'Micheal Smith',
#  'Sarah Lee',
#  'David Kim',
#  nan,
#  'John Brown',
#  'Emma Wilson',
#  'Tom Davis',
#  'Jane Miller',
#  'Chris Taylor']

# %%
#clean inconsistent value in department
df.replace({
    "hr": "HR",
    "MKting": "Marketing",
    "marketing": "Marketing"
}, inplace=True)
# Out:
#    Employee ID      Full Name     Department          Age    Salary  \
# 0          101  Alice Johnson             IT           29  $5500.50
# 1          102  Micheal Smith             HR  thirty-five      4800
# 2          103      Sarah Lee          Mktng           26   4200.75
# 3          104      David Kim             IT           31       NaN
# 4          105            NaN  Customer Care           42      6100
# 5          106     John Brown      Marketing           27     4,300
# 6          107    Emma Wilson        Finance           33      5800
# 7          108      Tom Davis            NaN           30      5000
# 8          109    Jane Miller             HR          NaN    4700.0
# 9          110   Chris Taylor      Marketing           28      4400
#
#         Join Date Performance Remote
# 0      12-04-2021          87    Yes
# 1      2020.11.01          73     No
# 2    Jan 18, 2022          90      Y
# 3       2019/9/25          65      N
# 4        07/05/18          82    yes
# 5      2021-10-14          75     no
# 6      2019/12/01          88      Y
# 7      2020-03-22         NaN    Yes
# 8  May 10th, 2021         79%    NaN
# 9      2022-02-05          91   True

# %%
#clean inconsistent values in age
def clean_age(value):
    if value == "thirty-five":
        return 35
    elif isinstance(value, (int, float)):
        return value
    elif isinstance(value, str) and value.isdigit():
        return int(value)
    else:
        return np.nan
df["Age"] = df["Age"].apply(clean_age)

df["Age"]
# Out:
# 0    29.0
# 1    35.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8     NaN
# 9    28.0
# Name: Age, dtype: float64

# %%
df
# Out:
#    Employee ID      Full Name     Department   Age    Salary       Join Date  \
# 0          101  Alice Johnson             IT  29.0  $5500.50      12-04-2021
# 1          102  Micheal Smith             HR  35.0      4800      2020.11.01
# 2          103      Sarah Lee          Mktng  26.0   4200.75    Jan 18, 2022
# 3          104      David Kim             IT  31.0       NaN       2019/9/25
# 4          105            NaN  Customer Care  42.0      6100        07/05/18
# 5          106     John Brown      Marketing  27.0     4,300      2021-10-14
# 6          107    Emma Wilson        Finance  33.0      5800      2019/12/01
# 7          108      Tom Davis            NaN  30.0      5000      2020-03-22
# 8          109    Jane Miller             HR   NaN    4700.0  May 10th, 2021
# 9          110   Chris Taylor      Marketing  28.0      4400      2022-02-05
#
#   Performance Remote
# 0          87    Yes
# 1          73     No
# 2          90      Y
# 3          65      N
# 4          82    yes
# 5          75     no
# 6          88      Y
# 7         NaN    Yes
# 8         79%    NaN
# 9          91   True

# %%
#clean inconsistent value in salary column
df["Salary"] = (
    df["Salary"]
    .astype(str)
    .replace('[$,]', "", regex=True)
    .replace("NaN", np.nan)
    .astype(float)
)

df["Salary"]
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3        NaN
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: Salary, dtype: float64

# %%
from dateutil import parser

def clean_date(date_str):
    try:
        return parser.parse(date_str, dayfirst=True)
    except Exception:
         return pd.NaT

df["Join Date"] = df["Join Date"].apply(clean_date)
df["Join Date"]
# Out:
# 0   2021-04-12
# 1   2020-01-11
# 2   2022-01-18
# 3   2019-09-25
# 4   2018-05-07
# 5   2021-10-14
# 6   2019-01-12
# 7   2020-03-22
# 8   2021-05-10
# 9   2022-05-02
# Name: Join Date, dtype: datetime64[us]

# %%
df["Performance"] = (
    df["Performance"]
    .astype(str)
    .replace("%", "", regex=True)
    .replace("None", np.nan)
    .astype(float)
)

df["Performance"]
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7     NaN
# 8    79.0
# 9    91.0
# Name: Performance, dtype: float64

# %%
df.replace({
    "Y": "Yes",
    "N": "No",
    "yes": "Yes",
    "no": "No",
    "None": np.nan,
    "True": "Yes"
},inplace=True)

df["Remote"]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    NaN
# 9    Yes
# Name: Remote, dtype: str

# %%
df["Employee ID"] = pd.to_numeric(df["Employee ID"], errors="coerce")
df["Employee ID"]
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: Employee ID, dtype: int64

# %%
#handling missing values
df["Full Name"] = df["Full Name"].fillna("Unknown")
df["Full Name"]
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: Full Name, dtype: str

# %%
df["Department"] = df["Department"].fillna(df["Department"].mode()[0])
df["Department"]
# Out:
# 0               IT
# 1               HR
# 2            Mktng
# 3               IT
# 4    Customer Care
# 5        Marketing
# 6          Finance
# 7               HR
# 8               HR
# 9        Marketing
# Name: Department, dtype: str

# %%
df["Age"] = df["Age"].fillna(df["Age"])
df["Age"]
# Out:
# 0    29.0
# 1    35.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8     NaN
# 9    28.0
# Name: Age, dtype: float64

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].median())
df["Salary"]
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3    4800.00
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: Salary, dtype: float64

# %%
df["Performance"] = df["Performance"].fillna(df["Performance"].median())
df["Performance"]
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7    82.0
# 8    79.0
# 9    91.0
# Name: Performance, dtype: float64

# %%
df["Remote"] = df["Remote"].fillna(df["Remote"].mode()[0])
df["Remote"]
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    Yes
# 9    Yes
# Name: Remote, dtype: str

# %%
#working with filtering data

# %%
df["Full Name"]
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: Full Name, dtype: str

# %%
df[["Full Name", "Department", "Salary"]]
# Out:
#        Full Name     Department   Salary
# 0  Alice Johnson             IT  5500.50
# 1  Micheal Smith             HR  4800.00
# 2      Sarah Lee          Mktng  4200.75
# 3      David Kim             IT  4800.00
# 4        Unknown  Customer Care  6100.00
# 5     John Brown      Marketing  4300.00
# 6    Emma Wilson        Finance  5800.00
# 7      Tom Davis             HR  5000.00
# 8    Jane Miller             HR  4700.00
# 9   Chris Taylor      Marketing  4400.00

# %%
df.iloc[0:11, 0:3]
# Out:
#    Employee ID      Full Name     Department
# 0          101  Alice Johnson             IT
# 1          102  Micheal Smith             HR
# 2          103      Sarah Lee          Mktng
# 3          104      David Kim             IT
# 4          105        Unknown  Customer Care
# 5          106     John Brown      Marketing
# 6          107    Emma Wilson        Finance
# 7          108      Tom Davis             HR
# 8          109    Jane Miller             HR
# 9          110   Chris Taylor      Marketing

# %%
df.iloc[0:3]
# Out:
#    Employee ID      Full Name Department   Age   Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.50 2021-04-12
# 1          102  Micheal Smith         HR  35.0  4800.00 2020-01-11
# 2          103      Sarah Lee      Mktng  26.0  4200.75 2022-01-18
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes

# %%
df.loc[df["Salary"] >= 5000] #conditional statement
# Out:
#    Employee ID      Full Name     Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson             IT  29.0  5500.5 2021-04-12
# 4          105        Unknown  Customer Care  42.0  6100.0 2018-05-07
# 6          107    Emma Wilson        Finance  33.0  5800.0 2019-01-12
# 7          108      Tom Davis             HR  30.0  5000.0 2020-03-22
#
#    Performance Remote
# 0         87.0    Yes
# 4         82.0    Yes
# 6         88.0    Yes
# 7         82.0    Yes

# %%
#df.loc(df["Salary"] >= 5000, ["Fullname"], ["Department"])

# %%
df.loc[:, "Salary"] #
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3    4800.00
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: Salary, dtype: float64

# %%
df[df["Department"] == "IT"]
# Out:
#    Employee ID      Full Name Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 3          104      David Kim         IT  31.0  4800.0 2019-09-25
#
#    Performance Remote
# 0         87.0    Yes
# 3         65.0     No

# %%
df[df["Age"] > 30]
# Out:
#    Employee ID      Full Name     Department   Age  Salary  Join Date  \
# 1          102  Micheal Smith             HR  35.0  4800.0 2020-01-11
# 3          104      David Kim             IT  31.0  4800.0 2019-09-25
# 4          105        Unknown  Customer Care  42.0  6100.0 2018-05-07
# 6          107    Emma Wilson        Finance  33.0  5800.0 2019-01-12
#
#    Performance Remote
# 1         73.0     No
# 3         65.0     No
# 4         82.0    Yes
# 6         88.0    Yes

# %%
df[
    (df["Salary"] >= 5000) & (df["Department"] == "IT")
]
# Out:
#    Employee ID      Full Name Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.5 2021-04-12
#
#    Performance Remote
# 0         87.0    Yes

# %%
df[
    (df["Salary"] >= 4000) | (df["Remote"] == "Yes")
]
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 9         91.0    Yes

# %%
df[df["Department"].str.startswith("M")]
# Out:
#    Employee ID     Full Name Department   Age   Salary  Join Date  \
# 2          103     Sarah Lee      Mktng  26.0  4200.75 2022-01-18
# 5          106    John Brown  Marketing  27.0  4300.00 2021-10-14
# 9          110  Chris Taylor  Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 2         90.0    Yes
# 5         75.0     No
# 9         91.0    Yes

# %%
df[df["Department"].isin(["IT", "HR"])]
# Out:
#    Employee ID      Full Name Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 1          102  Micheal Smith         HR  35.0  4800.0 2020-01-11
# 3          104      David Kim         IT  31.0  4800.0 2019-09-25
# 7          108      Tom Davis         HR  30.0  5000.0 2020-03-22
# 8          109    Jane Miller         HR   NaN  4700.0 2021-05-10
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 3         65.0     No
# 7         82.0    Yes
# 8         79.0    Yes

# %%
df[df["Full Name"].str.contains("john", case=False)]
# Out:
#    Employee ID      Full Name Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 5          106     John Brown  Marketing  27.0  4300.0 2021-10-14
#
#    Performance Remote
# 0         87.0    Yes
# 5         75.0     No

# %%
#working with sorting
df.sort_values("Salary", ascending=False)
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
#
#    Performance Remote
# 4         82.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 7         82.0    Yes
# 1         73.0     No
# 3         65.0     No
# 8         79.0    Yes
# 9         91.0    Yes
# 5         75.0     No
# 2         90.0    Yes

# %%
df.sort_values("Performance", ascending=False)
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
#
#    Performance Remote
# 9         91.0    Yes
# 2         90.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 4         82.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 5         75.0     No
# 1         73.0     No
# 3         65.0     No

# %%
df.sort_values(["Department", "Salary"], ascending=False)
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    Performance Remote
# 2         90.0    Yes
# 9         91.0    Yes
# 5         75.0     No
# 0         87.0    Yes
# 3         65.0     No
# 7         82.0    Yes
# 1         73.0     No
# 8         79.0    Yes
# 6         88.0    Yes
# 4         82.0    Yes

# %%
df.sort_values(["Department", "Salary"], ascending=[False, True])
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
#
#    Performance Remote
# 2         90.0    Yes
# 5         75.0     No
# 9         91.0    Yes
# 3         65.0     No
# 0         87.0    Yes
# 8         79.0    Yes
# 1         73.0     No
# 7         82.0    Yes
# 6         88.0    Yes
# 4         82.0    Yes

# %%
df["Department"].value_counts()
# Out:
# Department
# HR               3
# IT               2
# Marketing        2
# Mktng            1
# Customer Care    1
# Finance          1
# Name: count, dtype: int64

# %%
df["Department"].value_counts(normalize=True)
# Out:
# Department
# HR               0.3
# IT               0.2
# Marketing        0.2
# Mktng            0.1
# Customer Care    0.1
# Finance          0.1
# Name: proportion, dtype: float64

# %%
df["Remote"].value_counts(normalize=True)
# Out:
# Remote
# Yes    0.7
# No     0.3
# Name: proportion, dtype: float64

# %%
df
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 9         91.0    Yes

# %%
#merging two different types of data together
data1 = {
    "department": ["IT", "HR", "Finance", "Marketing", "R&D", "Operations", "Sales", "Logistics", "Procurement", "Customer Service"],
    "manager": [
        "Tom Hanks", "Susan Lee", "Robert Miles", 
        "Mark Chan", "Sarah Connor", "James Nwosu", "Adaeze Obi", 
        "Daniel Smith", "Amina Yusuf", "Grace Ojo"
    ],
    "department_budget": [200000, 150000, 250000, 180000, 300000, 220000, 210000, 195000, 230000, 170000],
    "office_location": [
        "Lagos", "Abuja", "Port Harcourt", "Ibadan", "Enugu", "Kano",
        "Lagos", "Calabar", "Abuja", "Kano"
    ]
}

df1 = pd.DataFrame(data1)

df1.to_csv("department_data.csv", index=False)

# %%
df1.rename(columns={
    "department": "Department",
    "manager": "Manager",
    "department_budget": "Department Budget",
    "office_location": "Office Location"
}, inplace=True)

df1
# Out:
#          Department       Manager  Department Budget Office Location
# 0                IT     Tom Hanks             200000           Lagos
# 1                HR     Susan Lee             150000           Abuja
# 2           Finance  Robert Miles             250000   Port Harcourt
# 3         Marketing     Mark Chan             180000          Ibadan
# 4               R&D  Sarah Connor             300000           Enugu
# 5        Operations   James Nwosu             220000            Kano
# 6             Sales    Adaeze Obi             210000           Lagos
# 7         Logistics  Daniel Smith             195000         Calabar
# 8       Procurement   Amina Yusuf             230000           Abuja
# 9  Customer Service     Grace Ojo             170000            Kano

# %%
#combining dataframe using pandas
merge_df = pd.merge(df, df1, on="Department", how="inner")
merge_df
# Out:
#    Employee ID      Full Name Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 1          102  Micheal Smith         HR  35.0  4800.0 2020-01-11
# 2          104      David Kim         IT  31.0  4800.0 2019-09-25
# 3          106     John Brown  Marketing  27.0  4300.0 2021-10-14
# 4          107    Emma Wilson    Finance  33.0  5800.0 2019-01-12
# 5          108      Tom Davis         HR  30.0  5000.0 2020-03-22
# 6          109    Jane Miller         HR   NaN  4700.0 2021-05-10
# 7          110   Chris Taylor  Marketing  28.0  4400.0 2022-05-02
#
#    Performance Remote       Manager  Department Budget Office Location
# 0         87.0    Yes     Tom Hanks             200000           Lagos
# 1         73.0     No     Susan Lee             150000           Abuja
# 2         65.0     No     Tom Hanks             200000           Lagos
# 3         75.0     No     Mark Chan             180000          Ibadan
# 4         88.0    Yes  Robert Miles             250000   Port Harcourt
# 5         82.0    Yes     Susan Lee             150000           Abuja
# 6         79.0    Yes     Susan Lee             150000           Abuja
# 7         91.0    Yes     Mark Chan             180000          Ibadan

# %%
outer_merge = pd.merge(df,df1, on="Department", how="outer")
outer_merge
# Out:
#     Employee ID      Full Name        Department   Age   Salary  Join Date  \
# 0         105.0        Unknown     Customer Care  42.0  6100.00 2018-05-07
# 1           NaN            NaN  Customer Service   NaN      NaN        NaT
# 2         107.0    Emma Wilson           Finance  33.0  5800.00 2019-01-12
# 3         102.0  Micheal Smith                HR  35.0  4800.00 2020-01-11
# 4         108.0      Tom Davis                HR  30.0  5000.00 2020-03-22
# 5         109.0    Jane Miller                HR   NaN  4700.00 2021-05-10
# 6         101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 7         104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 8           NaN            NaN         Logistics   NaN      NaN        NaT
# 9         106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 10        110.0   Chris Taylor         Marketing  28.0  4400.00 2022-05-02
# 11        103.0      Sarah Lee             Mktng  26.0  4200.75 2022-01-18
# 12          NaN            NaN        Operations   NaN      NaN        NaT
# 13          NaN            NaN       Procurement   NaN      NaN        NaT
# 14          NaN            NaN               R&D   NaN      NaN        NaT
# 15          NaN            NaN             Sales   NaN      NaN        NaT
#
#     Performance Remote       Manager  Department Budget Office Location
# 0          82.0    Yes           NaN                NaN             NaN
# 1           NaN    NaN     Grace Ojo           170000.0            Kano
# 2          88.0    Yes  Robert Miles           250000.0   Port Harcourt
# 3          73.0     No     Susan Lee           150000.0           Abuja
# 4          82.0    Yes     Susan Lee           150000.0           Abuja
# 5          79.0    Yes     Susan Lee           150000.0           Abuja
# 6          87.0    Yes     Tom Hanks           200000.0           Lagos
# 7          65.0     No     Tom Hanks           200000.0           Lagos
# 8           NaN    NaN  Daniel Smith           195000.0         Calabar
# 9          75.0     No     Mark Chan           180000.0          Ibadan
# 10         91.0    Yes     Mark Chan           180000.0          Ibadan
# 11         90.0    Yes           NaN                NaN             NaN
# 12          NaN    NaN   James Nwosu           220000.0            Kano
# 13          NaN    NaN   Amina Yusuf           230000.0           Abuja
# 14          NaN    NaN  Sarah Connor           300000.0           Enugu
# 15          NaN    NaN    Adaeze Obi           210000.0           Lagos

# %%
left_join = pd.merge(df, df1, on="Department", how="left")
left_join
# Out:
#    Employee ID      Full Name     Department   Age   Salary  Join Date  \
# 0          101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1          102  Micheal Smith             HR  35.0  4800.00 2020-01-11
# 2          103      Sarah Lee          Mktng  26.0  4200.75 2022-01-18
# 3          104      David Kim             IT  31.0  4800.00 2019-09-25
# 4          105        Unknown  Customer Care  42.0  6100.00 2018-05-07
# 5          106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6          107    Emma Wilson        Finance  33.0  5800.00 2019-01-12
# 7          108      Tom Davis             HR  30.0  5000.00 2020-03-22
# 8          109    Jane Miller             HR   NaN  4700.00 2021-05-10
# 9          110   Chris Taylor      Marketing  28.0  4400.00 2022-05-02
#
#    Performance Remote       Manager  Department Budget Office Location
# 0         87.0    Yes     Tom Hanks           200000.0           Lagos
# 1         73.0     No     Susan Lee           150000.0           Abuja
# 2         90.0    Yes           NaN                NaN             NaN
# 3         65.0     No     Tom Hanks           200000.0           Lagos
# 4         82.0    Yes           NaN                NaN             NaN
# 5         75.0     No     Mark Chan           180000.0          Ibadan
# 6         88.0    Yes  Robert Miles           250000.0   Port Harcourt
# 7         82.0    Yes     Susan Lee           150000.0           Abuja
# 8         79.0    Yes     Susan Lee           150000.0           Abuja
# 9         91.0    Yes     Mark Chan           180000.0          Ibadan

# %%
right_join = pd.merge(df, df1, on="Department", how="right")
right_join
# Out:
#     Employee ID      Full Name        Department   Age  Salary  Join Date  \
# 0         101.0  Alice Johnson                IT  29.0  5500.5 2021-04-12
# 1         104.0      David Kim                IT  31.0  4800.0 2019-09-25
# 2         102.0  Micheal Smith                HR  35.0  4800.0 2020-01-11
# 3         108.0      Tom Davis                HR  30.0  5000.0 2020-03-22
# 4         109.0    Jane Miller                HR   NaN  4700.0 2021-05-10
# 5         107.0    Emma Wilson           Finance  33.0  5800.0 2019-01-12
# 6         106.0     John Brown         Marketing  27.0  4300.0 2021-10-14
# 7         110.0   Chris Taylor         Marketing  28.0  4400.0 2022-05-02
# 8           NaN            NaN               R&D   NaN     NaN        NaT
# 9           NaN            NaN        Operations   NaN     NaN        NaT
# 10          NaN            NaN             Sales   NaN     NaN        NaT
# 11          NaN            NaN         Logistics   NaN     NaN        NaT
# 12          NaN            NaN       Procurement   NaN     NaN        NaT
# 13          NaN            NaN  Customer Service   NaN     NaN        NaT
#
#     Performance Remote       Manager  Department Budget Office Location
# 0          87.0    Yes     Tom Hanks             200000           Lagos
# 1          65.0     No     Tom Hanks             200000           Lagos
# 2          73.0     No     Susan Lee             150000           Abuja
# 3          82.0    Yes     Susan Lee             150000           Abuja
# 4          79.0    Yes     Susan Lee             150000           Abuja
# 5          88.0    Yes  Robert Miles             250000   Port Harcourt
# 6          75.0     No     Mark Chan             180000          Ibadan
# 7          91.0    Yes     Mark Chan             180000          Ibadan
# 8           NaN    NaN  Sarah Connor             300000           Enugu
# 9           NaN    NaN   James Nwosu             220000            Kano
# 10          NaN    NaN    Adaeze Obi             210000           Lagos
# 11          NaN    NaN  Daniel Smith             195000         Calabar
# 12          NaN    NaN   Amina Yusuf             230000           Abuja
# 13          NaN    NaN     Grace Ojo             170000            Kano

# %%
merge_df
# Out:
#    Employee ID      Full Name Department   Age  Salary  Join Date  \
# 0          101  Alice Johnson         IT  29.0  5500.5 2021-04-12
# 1          102  Micheal Smith         HR  35.0  4800.0 2020-01-11
# 2          104      David Kim         IT  31.0  4800.0 2019-09-25
# 3          106     John Brown  Marketing  27.0  4300.0 2021-10-14
# 4          107    Emma Wilson    Finance  33.0  5800.0 2019-01-12
# 5          108      Tom Davis         HR  30.0  5000.0 2020-03-22
# 6          109    Jane Miller         HR   NaN  4700.0 2021-05-10
# 7          110   Chris Taylor  Marketing  28.0  4400.0 2022-05-02
#
#    Performance Remote       Manager  Department Budget Office Location
# 0         87.0    Yes     Tom Hanks             200000           Lagos
# 1         73.0     No     Susan Lee             150000           Abuja
# 2         65.0     No     Tom Hanks             200000           Lagos
# 3         75.0     No     Mark Chan             180000          Ibadan
# 4         88.0    Yes  Robert Miles             250000   Port Harcourt
# 5         82.0    Yes     Susan Lee             150000           Abuja
# 6         79.0    Yes     Susan Lee             150000           Abuja
# 7         91.0    Yes     Mark Chan             180000          Ibadan

# %%
#avg salary of employee
print(merge_df["Salary"].mean())
# Out:
# 4912.5625

# %%
merge_df.describe()
# Out:
#        Employee ID        Age       Salary            Join Date  Performance  \
# count     8.000000   7.000000     8.000000                    8     8.000000
# mean    105.875000  30.428571  4912.562500  2020-09-20 03:00:00    80.000000
# min     101.000000  27.000000  4300.000000  2019-01-12 00:00:00    65.000000
# 25%     103.500000  28.500000  4625.000000  2019-12-15 00:00:00    74.500000
# 50%     106.500000  30.000000  4800.000000  2020-10-01 00:00:00    80.500000
# 75%     108.250000  32.000000  5125.125000  2021-06-18 06:00:00    87.250000
# max     110.000000  35.000000  5800.000000  2022-05-02 00:00:00    91.000000
# std       3.270539   2.819997   513.995236                  NaN     8.766821
#
#        Department Budget
# count           8.000000
# mean       182500.000000
# min        150000.000000
# 25%        150000.000000
# 50%        180000.000000
# 75%        200000.000000
# max        250000.000000
# std         34537.764011

# %%
#avg salary by department
merge_df.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance      5800.000000
# HR           4833.333333
# IT           5150.250000
# Marketing    4350.000000
# Name: Salary, dtype: float64

# %%
merge_df["Department Avg Salary"] = merge_df.groupby("Department")["Salary"].transform("mean")

# %%
#avg performance by department
merge_df.groupby("Department")["Performance"].mean()
# Out:
# Department
# Finance      88.0
# HR           78.0
# IT           76.0
# Marketing    83.0
# Name: Performance, dtype: float64

# %%
#visualize avg salary by department
plt.bar(merge_df["Department"], merge_df["Department Avg Salary"])
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.grid(axis='y', linestyle="--", alpha=0.7)
plt.show()

# %%
#view proportion remote vs onsite
remote_status = ["Remote", "Onsite"]
plt.pie(merge_df["Remote"].value_counts(), labels=remote_status, autopct="%1.1f%%")
plt.title("Distribution for Remote Employee")
plt.show()

# %%
#visiualize stack chart for department average salary and department budget
plt.bar(merge_df["Department"], merge_df["Department Budget"], color="lightblue", label="Budget")
plt.bar(merge_df["Department"], merge_df["Department Avg Salary"], color="orange", label="Salary")
plt.title("Average Salary and Department Budget by Department")
plt.xlabel("Department")
plt.ylabel("Average Salary and Department Budget")
plt.show()

# %%
#visualize employee by performance overtime
plt.plot(merge_df["Full Name"], merge_df["Performance"], color="green", marker="o")
plt.title("Employee by Performance Overtime")
plt.xlabel("Employee Name")
plt.ylabel("Performance")
plt.xticks(rotation=90)
plt.show()

# %%
#visualising relationshop between performance and salary
plt.scatter(merge_df["Salary"], merge_df["Performance"], color="orange")
plt.title("Relationship between Performance and Salary")
plt.xlabel("Salary")
plt.grid(linestyle="--", alpha=0.7)
plt.ylabel("Performance")
plt.show()

# %%
#visualize the distribution of salary by employee
plt.hist(merge_df["Salary"], bins=6, edgecolor="white", color="orange")
plt.title("Distribution of Salary by Employee")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()

# %%
#visualize he correlation matrix for numerical cols
numerical_cols=["Age", "Salary", "Performance", "Department Budget", "Department Avg Salary"]
corr = merge_df[numerical_cols].corr()


sns.heatmap(corr, annot=True, cmap="vlag", fmt=".2f", linewidth="0.5", linecolor="blue")
plt.title("Correlation Matrix for Employee Numerical Columns")
plt.show()

# %%
#visualize the correlation of employee numerical columns
sns.pairplot(merge_df[numerical_cols], diag_kind="kde")
plt.suptitle("Pair plot for numerical columns", y=1.05)
plt.show()

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=merge_df[col])
    plt.title(col)
    plt.tight_layout()
plt.show()

# %%
#detect outliers
Q1 = merge_df["Salary"].quantile(0.25)
Q3 = merge_df["Salary"].quantile(0.75)

IQR = Q3 - Q1

lower_bond = Q1 - 1.5 * IQR
upper_bond = Q3 + 1.5 * IQR

detect_outliers = (
    (merge_df["Salary"] < lower_bond) | (merge_df["Salary"] > upper_bond)
)

new_df = merge_df[
    (merge_df["Salary"] > lower_bond) & (merge_df["Salary"] < upper_bond)
    ]
new_df
print(detect_outliers.sum())
print(lower_bond)
print(upper_bond)
# Out:
# 0
# 3874.8125
# 5875.3125

# %%
#distribution value for department using pie chart
dept_count = new_df["Department"].value_counts()
fig = px.pie(
    values=dept_counts.value,
    index=dept_counts.index,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 3
#       1 #distribution value for department using pie chart
#       2 dept_count = new_df["Department"].value_counts()
# ----> 3 fig = px.pie(
#       4     values=dept_counts.value,
#       5     index=dept_counts.index,
#       6 )
#
# NameError: name 'px' is not defined

# %%
#visualizing avg salary by dept
avg_salary = new_df.groupby("Department")["Salary"].mean().sort_values(ascending=False)
fig1 = px.bar(
    x=avg_salary.values,
    y=avg_salary.index,
    title="Average Salary By Department"
)

fig1.update_layout(
    xaxis_title="Average Salary",
    yaxis_title="Department"
)

fig1.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 3
#       1 #visualizing avg salary by dept
#       2 avg_salary = new_df.groupby("Department")["Salary"].mean().sort_values(ascending=False)
# ----> 3 fig1 = px.bar(
#       4     x=avg_salary.values,
#       5     y=avg_salary.index,
#       6     title="Average Salary By Department"
#
# NameError: name 'px' is not defined

# %%
#distribution of employee performance

fig2 = px.histogram(
    new_df,
    x="Performance",
    nbins=6,
    title="Distribution Of Employee Performance"
)
fig2.update_traces(
    marker_line_color="white",
    marker_line_width = 1
)
fig2.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 #distribution of employee performance
#       2
# ----> 3 fig2 = px.histogram(
#       4     new_df,
#       5     x="Performance",
#       6     nbins=6,
#
# NameError: name 'px' is not defined

# %%
fig3 = px.box(
    new_df,
    y="Salary",
    title="Boxplot Salary"
)
fig3.show()

# %%
fig4 = px.box(
    new_df,
    y="Department Budget",
    title="Boxplot Salary"
)
fig4.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 fig4 = px.box(
#       2     new_df,
#       3     y="Department Budget",
#       4     title="Boxplot Salary"
#
# NameError: name 'px' is not defined

# %%
new_df.to_csv("Employee_cleaned_dataset.csv")
